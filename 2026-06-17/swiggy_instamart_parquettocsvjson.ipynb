# %%
import pandas as pd
df = pd.read_parquet("swiggy_instamart_2026_06_16.parquet")



df
# Out:
#        crawl_date_and_time     platform_name  store_id  store_name_location  \
# 0      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 1      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 2      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 3      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 4      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# ...                    ...               ...       ...                  ...
# 11757  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11758  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11759  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11760  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11761  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
#
# ...

# %%
# converting the file into csv

converting_to_csv =df.to_csv("swiggy_instamart_2026_06_16.csv", index= False)

# %%
pd.read_csv("swiggy_instamart_2026_06_16.csv")
# Out:
#        crawl_date_and_time     platform_name  store_id  store_name_location  \
# 0      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 1      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 2      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 3      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 4      2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# ...                    ...               ...       ...                  ...
# 11757  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11758  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11759  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11760  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11761  2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
#
# ...

# %%
# converting into jason file the parquet format


converting_to_json = df.to_json("swiggy_instamart_2026_06_16.json", orient="records", indent =4)

# %%
pd.read_json("swiggy_instamart_2026_06_16.json")
# Out:
#       crawl_date_and_time     platform_name  store_id  store_name_location  \
# 0     2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 1     2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 2     2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 3     2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# 4     2026-06-13 13:13:16  swiggy instamart   1386719                  NaN
# ...                   ...               ...       ...                  ...
# 11757 2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11758 2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11759 2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11760 2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
# 11761 2026-06-13 13:27:46  swiggy instamart   1386719                  NaN
#
#        city  pin_code   unique_id product_id_upc_ean  department  \
# ...

# %%
import os
os.system("java -version")
