# %%
# "facets": {
#                 "spol": {
#                     "unisex": 71168,
#                     "female": 45573,
#                     "male": 20775
#                 },   filers fo the geneder inside the product api we will get




#  "Lattafa Perfumes":1149204   ------------------------- filters for the creatures
# "Dior":503818
# "Yves Saint Laurent":492503
# "Guerlain":474603
# "Giorgio Armani":451528
# "Tom Ford":407814
# "French Avenue":396602
# "Jean Paul Gaultier":368405
# "Armaf":363116
# "Chanel":329713
