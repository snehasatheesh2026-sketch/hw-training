# %%
import requests 

from parsel import Selector

# %%
url = 'https://books.toscrape.com/'

# headers = {
#     'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
#     'accept-language': 'en-IN,en-GB;q=0.9,en-US;q=0.8,en;q=0.7',
#     'cache-control': 'max-age=0',
#     'if-modified-since': 'Wed, 08 Feb 2023 21:02:32 GMT',
#     'if-none-match': 'W/"63e40de8-c85e"',
#     'priority': 'u=0, i',
#     'sec-ch-ua': '"Chromium";v="148", "Google Chrome";v="148", "Not/A)Brand";v="99"',
#     'sec-ch-ua-mobile': '?0',
#     'sec-ch-ua-platform': '"Linux"',
#     'sec-fetch-dest': 'document',
#     'sec-fetch-mode': 'navigate',
#     'sec-fetch-site': 'none',
#     'sec-fetch-user': '?1',
#     'upgrade-insecure-requests': '1',
#     'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/148.0.0.0 Safari/537.36',
# }

respoance = requests.get(url)


print(respoance.status_code)

selectors = Selector(text = respoance.text)
# Out:
# 200

# %%
print(selectors)
# Out:
# <html lang="en-us" class="no-js"> <!--<![endif]-->
#     <head>
#         <title>
#     All products | Books to Scrape - Sandbox
# </title>
#
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <meta name="created" content="24th Jun 2016 09:29">
#         <meta name="description" content="">
#         <meta name="viewport" content="width=device-width">
#         <meta name="robots" content="NOARCHIVE,NOCACHE">
#
#         <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#         <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#
#
#             <link rel="shortcut icon" href="static/oscar/favicon.ico">
#
#
#
#
#
#
#         <link rel="stylesheet" type="text/css" href="static/oscar/css/styles.css">
#
#     <link rel="stylesheet" href="static/oscar/js/bootstrap-datetimepicker/bootstrap-datetimepicker.css">
# ...

# %%
products = selectors.xpath('//article[@class="product_pod"]')

# %%
print(products)
# Out:
# [<Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n       ...'>, <Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n       ...'>, <Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n       ...'>, <Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n       ...'>, <Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n       ...'>, <Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n       ...'>, <Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n       ...'>, <Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n       ...'>, <Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n       ...'>, <Selector query='//article[@class="product_pod"]' data='<article class="product_pod">\n 
# ...

# %%
print(len(products))
# Out:
# 20

# %%
product_url = products.xpath('.//h3/a/@href').getall()

# %%
for i in product_url:

    print(i)
# Out:
# catalogue/a-light-in-the-attic_1000/index.html
# catalogue/tipping-the-velvet_999/index.html
# catalogue/soumission_998/index.html
# catalogue/sharp-objects_997/index.html
# catalogue/sapiens-a-brief-history-of-humankind_996/index.html
# catalogue/the-requiem-red_995/index.html
# catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html
# catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html
# catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html
# catalogue/the-black-maria_991/index.html
# catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html
# catalogue/shakespeares-sonnets_989/index.html
# catalogue/set-me-free_988/index.html
# catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html
# catalogue/rip-it-up-and-start-again_986/index.html
# ...

# %%
product_name  =products.xpath('.//h3/a/@title').getall()  # the dot is repersent only search inside the product

# %%
print(product_name)
# Out:
# ['A Light in the Attic', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History of Humankind', 'The Requiem Red', 'The Dirty Little Secrets of Getting Your Dream Job', 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', 'The Black Maria', 'Starving Hearts (Triangular Trade Trilogy, #1)', "Shakespeare's Sonnets", 'Set Me Free', "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", 'Rip it Up and Start Again', 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', 'Olio', 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'Libertarianism for Beginners', "It's Only the Himalayas"]

# %%
product_price = products.xpath('.//p[@class="price_color"]/text()').get().replace("Â£","")

# %%
product_price
# Out:
# '51.77'

# %%
stock_availvabity = products.xpath('normalize-space(.//p[contains(@class,"availability")])').getall()  # normalize space

# %%
stock_availvabity
# Out:
# ['In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock',
#  'In stock']

# %%
# if the class name is not get correctly we can perform like this example : class="star-rating Three"

product_rating = products.xpath('.//p[contains(@class,"star-rating")]/@class').getall()

# %%
for i in product_rating:

    print(i.split()[-1])
# Out:
# Three
# One
# One
# Four
# Five
# One
# Four
# Three
# Four
# One
# Two
# Four
# Five
# Five
# Five
# Three
# One
# One
# Two
# Two

# %%
categories = products.xpath('//div[@class="side_categories"]//a')

for category in categories:
    print(category.xpath('normalize-space(.)').get())
# Out:
# Books
# Travel
# Mystery
# Historical Fiction
# Sequential Art
# Classics
# Philosophy
# Romance
# Womens Fiction
# Fiction
# Childrens
# Religion
# Nonfiction
# Music
# Default
# Science Fiction
# Sports and Games
# Add a comment
# Fantasy
# New Adult
# Young Adult
# Science
# Poetry
# Paranormal
# Art
# Psychology
# Autobiography
# Parenting
# Adult Fiction
# Humor
# Horror
# History
# Food and Drink
# Christian Fiction
# Business
# Biography
# Thriller
# Contemporary
# Spirituality
# Academic
# Self Help
# Historical
# Christian
# Suspense
# Short Stories
# Novels
# Health
# Politics
# Cultural
# Erotica
# Crime
# Books
# Travel
# Mystery
# Historical Fiction
# Sequential Art
# Classics
# Philosophy
# Romance
# Womens Fiction
# Fiction
# Childrens
# Religion
# Nonfiction
# Music
# Default
# Science Fiction
# Sports and Games
# Add a comment
# Fantasy
# New Adult
# Young Adult
# Science
# Poetry
# Paranormal
# Art
# Psychology
# Autobiography
# Parenting
# Adult Fiction
# Humor
# ...

# %%
for pro in products:

    print(pro.xpath('.//ul[@class="breadcrumb"])').get())  #/li[3]
# li = list item inside <ul>
# [3] = 3rd <li> element
# Out:
# ---------------------------------------------------------------------------
# XPathEvalError                            Traceback (most recent call last)
# File ~/Desktop/trainig/scrapy/lib/python3.10/site-packages/parsel/selector.py:602, in Selector.xpath(self, query, namespaces, **kwargs)
#     601 try:
# --> 602     result = xpathev(
#     603         query,
#     604         namespaces=nsp,
#     605         smart_strings=self._lxml_smart_strings,
#     606         **kwargs,
#     607     )
#     608 except etree.XPathError as exc:
#
# File src/lxml/etree.pyx:1727, in lxml.etree._Element.xpath()
#
# File src/lxml/xpath.pxi:290, in lxml.etree.XPathElementEvaluator.__call__()
#
# File src/lxml/xpath.pxi:210, in lxml.etree._XPathEvaluatorBase._handle_result()
#
# XPathEvalError: Invalid expression
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 3
# ...

# %%
print(products.xpath('normalize-space(string(//div[@class="side_categories"]))').get())
# Out:
# Books Travel Mystery Historical Fiction Sequential Art Classics Philosophy Romance Womens Fiction Fiction Childrens Religion Nonfiction Music Default Science Fiction Sports and Games Add a comment Fantasy New Adult Young Adult Science Poetry Paranormal Art Psychology Autobiography Parenting Adult Fiction Humor Horror History Food and Drink Christian Fiction Business Biography Thriller Contemporary Spirituality Academic Self Help Historical Christian Suspense Short Stories Novels Health Politics Cultural Erotica Crime

# %%
response = requests.get('https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html'
)

# %%
product_selector = Selector(response.text)

description = product_selector.xpath(
        '//div[@id="product_description"]/following-sibling::p/text()'
    ).get()

print(description)
# Out:
# It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love th It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love that Silverstein. Need proof of his genius? RockabyeRockabye baby, in the treetopDon't you know a treetopIs no safe place to rock?And who put you up there,And your cradle, too?Baby, I think someone down here'sGot it in for you. Shel, you never sound
# ...

# %%
import requests

from parsel import Selector

from urllib.parse import urljoin


class book_spider:

    def __init__(self):
        

        self.url = "https://books.toscrape.com/"

        self.starting_url = "https://books.toscrape.com/catalogue/page-1.html"

        self.all_items = []

        def parse(self, urls):

            print(f"scrapping page: {urls}")

            respoance = requests.get(urls)

            if respoance.status_code != 200:

                return "the page is not acessable"
            
            selectors = Selector(text = respoance.text)

            product_list = selectors.xpath('//article[@class="product_pod"]')

            for product in product_list:

                categories = product.xpath('//div[@class="side_categories"]//a')

                try:
                    item_data = {
                    "name": product.xpath('.//h3/a/@title').get().strip(),
                    "price": product.xpath('.//p[@class="price_color"]/text()').get().replace("Â£",""),
                    "link": products.xpath(
                        './/a[contains(@class, "product-item-link")]/@href'
                    ).get(),
                    "stock_availvabity": product.xpath('normalize-space(.//p[contains(@class,"availability")])').get(),
                    
                }
                self.all_items.append(item_data)
# Out:
#   Cell In[33], line 44
#     self.all_items.append(item_data)
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
